# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('data.xml')

# %%
print(type(tree))
# Out:
# <class 'xml.etree.ElementTree.ElementTree'>

# %%
root = tree.getroot()
root
# Out:
# <Element 'data' at 0x7fb9fba6fe50>

# %%
print(root.tag)
print(root.attrib)
print(len(root))
# Out:
# data
# {}
# 3

# %%
country1 = root[0]
rank = country1[0]
print(rank.tag)
# What is the text inside this grandchild
print(rank.text)
# What are the attributes of last element?
print(country1[4].attrib)
# Out:
# rank
# 1
# {'name': 'Switzerland', 'direction': 'W'}

# %%
country3 = root[2]

# %%
rank = country3[0]
print(rank.tag)
# What is the text inside this grandchild
print(rank.text)
# What are the attributes of last element?
print(country3[4].attrib)
# Out:
# rank
# 68
# {'name': 'Colombia', 'direction': 'E'}

# %%
country1
# Out:
# <Element 'country' at 0x7fb9fac887c0>

# %%
for country in root.findall('country'):
    rank = country.find('rank').text
    name = country.get('name')
    print(name, rank)
# Out:
# Liechtenstein 1
# Singapore 4
# Panama 68

# %%
root.findall(".")
# Out:
# [<Element 'data' at 0x7fb9fba6fe50>]

# %%
root.findall("./country/neighbor")
# Out:
# [<Element 'neighbor' at 0x7fb9fb0a8720>,
#  <Element 'neighbor' at 0x7fb9fac397c0>,
#  <Element 'neighbor' at 0x7fb9fba917c0>,
#  <Element 'neighbor' at 0x7fb9fba91950>,
#  <Element 'neighbor' at 0x7fb9fba919a0>]

# %%
print(tree)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x7fb9fb09a130>

# %%
root
# Out:
# <Element 'data' at 0x7fb9fba6fe50>

# %%
country1.get("name")
# Out:
# 'Liechtenstein'

# %%
my_dict = {
            'name': [],
            'rank': [],
            'year': [],
            'gdppc': []
}

for country in root:
    my_dict['name'].append(country.get('name'))
    my_dict['rank'].append(country[0].text)
    my_dict['year'].append(country[1].text)
    my_dict['gdppc'].append(country[2].text)
    
df = pd.DataFrame(my_dict)

# %%
import pandas as pd

# %%
df
# Out:
#             name rank  year   gdppc
# 0  Liechtenstein    1  2008  141100
# 1      Singapore    4  2011   59900
# 2         Panama   68  2011   13600

# %%
tree = ET.parse('mondial.xml')

# %%
root = tree.getroot()
root
# Out:
# <Element 'mondial' at 0x7fb9fd3dd770>

# %%
print(root.tag)
print(root.attrib)
print(len(root))
# Out:
# mondial
# {}
# 3403

# %%
root[0]
# Out:
# <Element 'country' at 0x7fb9fd3dd9f0>

# %%
mydict = {
    'country': [],
    'infant_mortality': []
}

for country in root.findall('country'):
    try:
        mort = country.find('infant_mortality').text
        name = country.find('name').text
        mydict['country'].append(name)
        mydict['infant_mortality'].append(mort)
    except:
        AttributeError
        pass

# %%
df = pd.DataFrame(mydict)

# %%
for country in root.findall('country'):
    try:
        mort = country.find('infant_mortality').text
        name = country.find('name').text
        print(name, mort)
    except:
        AttributeError
        pass
# Out:
# Albania 13.19
# Greece 4.78
# North Macedonia 7.9
# Serbia 6.16
# Andorra 3.69
# France 3.31
# Spain 2.7
# Austria 4.16
# Czech Republic 2.63
# Germany 3.46
# Hungary 5.09
# Italy 3.31
# Liechtenstein 4.33
# Slovakia 5.35
# Slovenia 4.04
# Switzerland 3.73
# Belarus 3.64
# Latvia 7.91
# Lithuania 6
# Poland 6.19
# Ukraine 8.1
# Russia 7.08
# Belgium 4.18
# Luxembourg 4.28
# Netherlands 3.66
# Bosnia and Herzegovina 5.84
# Croatia 5.87
# Bulgaria 15.08
# Romania 10.16
# Turkey 21.43
# Denmark 4.1
# Estonia 6.7
# Faroe Islands 5.71
# Finland 3.36
# Norway 2.48
# Sweden 2.6
# Monaco 1.81
# Gibraltar 6.29
# Guernsey 3.47
# Iceland 3.15
# Ireland 3.74
# San Marino 4.52
# Jersey 3.86
# Malta 3.59
# Isle of Man 4.17
# Moldova 12.93
# Portugal 4.48
# United Kingdom 4.44
# Afghanistan 117.23
# China 14.79
# Iran 39
# Pakistan 57.48
# Tajikistan 35.03
# Turkmenistan 38.13
# Uzbekistan 19.84
# Armenia 13.97
# Georgia 16.68
# Azerbaijan 26.67
# Bahrain 9.68
# Bangladesh 45.67
# Myanmar 44.91
# India 43.19
# Bhutan 37.89
# Brunei 10.48
# Malaysia 13.69
# Laos 54.53
# Thailand 9.86
# Cambodia 51.36
# Vietnam 18.99
# Kazakhstan 21.61
# North Korea 24.5
# Kyrgyzstan 28.71
# Hong Kong 2.73
# Macao 3.13
# Mongolia 23.15
# Nepal 40.43
# Cyprus 8.54
# Gaza Strip 30.6
# Israel 3.98
# Egypt 22.41
# Indonesia 25.16
# Timor-Leste 38.79
# Papua New Guinea 39.67
# Iraq 37.53
# Jordan 15.73
# Kuwait 7.51
# Saudi Arabia 14.58
# Syria 15.79
# Lebanon 7.98
# West Bank 28.6
# Japan 2.13
# South Korea 3.93
# Maldives 24.59
# Oman 14
# United Arab Emirates 10.92
# Yemen 50.41
# Philippines 17.64
# Qatar 6.42
# Singapore 2.53
# Sri Lanka 9.02
# Taiwan 4.49
# Anguilla 3.4
# Antigua and Barbuda 13.29
# Aruba 11.74
# Bahamas 12.5
# Barbados 10.93
# Belize 20.31
# Guatemala 23.51
# Mexico 12.58
# Bermuda 2.48
# British Virgin Islands 13.45
# Canada 4.71
# United States 6.17
# Cayman Islands 6.21
# Costa Rica 8.7
# Nicaragua 20.36
# Panama 10.7
# Cuba 4.7
# Dominica 11.61
# Dominican Republic 19.63
# Haiti 49.43
# El Salvador 18.44
# Honduras 18.72
# Greenland 9.42
# Grenada 10.5
# Guadeloupe 8.3
# Jamaica 13.69
# Martinique 7.1
# Montserrat 13.66
# Sint Maarten 9.05
# Colombia 15.02
# Puerto Rico 7.73
# Saint Kitts and Nevis 8.98
# Saint Lucia 11.75
# Saint Pierre and Miquelon 6.95
# Saint Vincent and the Grenadines 13.07
# Trinidad and Tobago 24.82
# Turks and Caicos Islands 10.97
# Virgin Islands 6.79
# American Samoa 8.92
# Australia 4.43
# Cook Islands 14.33
# Fiji 10.2
# French Polynesia 4.78
# Guam 5.51
# Kiribati 35.37
# Marshall Islands 21.39
# Micronesia 21.93
# Nauru 8.21
# New Caledonia 5.46
# New Zealand 4.59
# Northern Mariana Islands 5.5
# Palau 11.46
# Solomon Islands 16.17
# Tonga 12.36
# Tuvalu 31.69
# Vanuatu 16.41
# Wallis and Futuna 4.49
# Samoa 20.5
# Argentina 9.96
# Bolivia 38.61
# Brazil 19.21
# Chile 7.02
# Paraguay 20.75
# Uruguay 8.97
# Peru 20.21
# French Guiana 14.6
# Guyana 33.56
# Suriname 27.07
# Venezuela 19.33
# Ecuador 17.93
# Algeria 21.76
# Libya 11.87
# Mali 104.34
# Mauritania 56.06
# Morocco 24.52
# Niger 86.27
# Tunisia 23.19
# Western Sahara 145.82
# Angola 79.99
# Congo 59.34
# Namibia 45.64
# Zaire 73.15
# Zambia 66.62
# Benin 57.09
# Burkina Faso 76.8
# Nigeria 74.09
# Togo 46.73
# Botswana 9.38
# South Africa 41.61
# Zimbabwe 26.55
# Cote d'Ivoire 60.16
# Ghana 38.52
# Burundi 63.44
# Rwanda 59.59
# Tanzania 43.74
# Cameroon 55.1
# Central African Republic 92.86
# Chad 90.3
# Equatorial Guinea 71.12
# Gabon 47.03
# Cape Verde 24.28
# Sudan 52.86
# South Sudan 68.16
# Comoros 65.31
# Guinea 55.24
# Liberia 69.19
# Djibouti 50.2
# Eritrea 38.44
# Ethiopia 55.77
# Somalia 100.14
# Kenya 40.71
# Gambia 65.74
# Senegal 52.72
# Guinea-Bissau 90.92
# Sierra Leone 73.29
# Uganda 60.82
# Lesotho 50.48
# Madagascar 44.88
# Malawi 48.01
# Mozambique 72.42
# Mauritius 10.59
# Mayotte 56.29
# Swaziland 54.82
# Reunion 7.5
# Saint Helena 17.63
# Sao Tome and Principe 49.16
# Seychelles 10.77

# %%
root.tag
# Out:
# 'mondial'

# %%
root[0].tag
# Out:
# 'country'

# %%
root[4].tag
# Out:
# 'country'

# %%
root[6].find('name').text
# Out:
# 'Andorra'

# %%
df.sort_values(by='infant_mortality', ascending=False).head(10)
# Out:
#                       country infant_mortality
# 197  Central African Republic            92.86
# 214             Guinea-Bissau            90.92
# 198                      Chad             90.3
# 159                 Argentina             9.96
# 66                   Thailand             9.86
# 58                    Bahrain             9.68
# 123                 Greenland             9.42
# 188                  Botswana             9.38
# 129              Sint Maarten             9.05
# 99                  Sri Lanka             9.02

# %%
mydict1 = {
    'city' : [],
    'population' : []}

# %%
for city in root.iter('city'):
    try:
        mydict1['city'].append(city.find('name').text)
        mydict1['population'].append(city.find('population').text)
    except:
        AttributeError
        pass

# %%
for city in root.iter('city'):
    print(city.)
# Out:
# {'id': 'cty-Albania-Tirane', 'country': 'AL'}
# {'id': 'stadt-Shkoder-AL-AL', 'country': 'AL'}
# {'id': 'stadt-Durres-AL-AL', 'country': 'AL'}
# {'id': 'stadt-Vlore-AL-AL', 'country': 'AL'}
# {'id': 'stadt-Elbasan-AL-AL', 'country': 'AL'}
# {'id': 'stadt-Korce-AL-AL', 'country': 'AL'}
# {'id': 'cty-Greece-Komotini', 'country': 'GR', 'province': 'prov-Greece-2'}
# {'id': 'cty-Greece-9', 'country': 'GR', 'province': 'prov-Greece-2'}
# {'id': 'cty-Greece-Athens', 'country': 'GR', 'province': 'prov-Greece-3'}
# {'id': 'cty-Greece-4', 'country': 'GR', 'province': 'prov-Greece-3'}
# {'id': 'cty-Greece-Peristeri', 'country': 'GR', 'province': 'prov-Greece-3'}
# {'id': 'cty-Greece-Acharnes', 'country': 'GR', 'province': 'prov-Greece-3'}
# {'id': 'cty-Greece-5', 'country': 'GR', 'province': 'prov-Greece-4'}
# {'id': 'cty-Greece-Kozani', 'country': 'GR', 'province': 'prov-Greece-5'}
# {'id': 'cty-Greece-Korfu', 'country': 'GR', 'province': 'prov-Greece-6'}
# {'id': 'cty-Greece-Ioannina', 'country': 'GR', 'province': 'prov-Greece-7'}
# {'id': 'cty-Greece-Thessaloniki', 'country': 'GR', 'province': 'prov-Greece-8'}
# {'id': 'cty-Greece-7', 'country': 'GR', 'province': 'prov-Greece-9'}
# {'id': 'cty-Greece-Chania', 'country': 'GR', 'province': 'prov-Greece-9'}
# {'id': 'cty-Greece-Ermoupoli', 'country': 'GR', 'province': 'prov-Greece-10'}
# {'id': 'cty-Greece-Rhodes', 'country': 'GR', 'province': 'prov-Greece-10'}
# {'id': 'cty-Greece-Tripoli', 'country': 'GR', 'province': 'prov-Greece-11'}
# {'id': 'cty-Greece-Lamia', 'country': 'GR', 'province': 'prov-Greece-12'}
# {'id': 'cty-Greece-Chalkida', 'country': 'GR', 'province': 'prov-Greece-12'}
# {'id': 'cty-Greece-6', 'country': 'GR', 'province': 'prov-Greece-13'}
# {'id': 'cty-Greece-8', 'country': 'GR', 'province': 'prov-Greece-13'}
# {'id': 'cty-Greece-Mytilini', 'country': 'GR', 'province': 'prov-Greece-14'}
# {'id': 'cty-Greece-Karyes', 'country': 'GR', 'province': 'prov-Greece-15'}
# {'id': 'cty-Macedonia-Skopje', 'country': 'MK'}
# {'id': 'cty-Macedonia-Kumanovo', 'country': 'MK'}
# {'id': 'city-Belgrade-SRB-SRB', 'country': 'SRB'}
# {'id': 'city-NoviSad-SRB-SRB', 'country': 'SRB'}
# {'id': 'city-Nis-SRB-SRB', 'country': 'SRB'}
# {'id': 'city-Podgorica-MNE-MNE', 'country': 'MNE'}
# {'id': 'city-Pristina-KOS-KOS', 'country': 'KOS'}
# {'id': 'cty-Andorra-Andorra-la-Vella', 'country': 'AND'}
# {'id': 'cty-France-Paris', 'country': 'F', 'province': 'prov-France-53'}
# {'id': 'cty-France-36', 'country': 'F', 'province': 'prov-France-53'}
# {'id': 'cty-France-38', 'country': 'F', 'province': 'prov-France-53'}
# {'id': 'cty-France-39', 'country': 'F', 'province': 'prov-France-53'}
# {'id': 'cty-France-40', 'country': 'F', 'province': 'prov-France-53'}
# {'id': 'cty-France-22', 'country': 'F', 'province': 'prov-France-11'}
# {'id': 'cty-France-Lyon', 'country': 'F', 'province': 'prov-France-11'}
# {'id': 'cty-France-17', 'country': 'F', 'province': 'prov-France-11'}
# {'id': 'cty-France-11', 'country': 'F', 'province': 'prov-France-11'}
# {'id': 'cty-France-29', 'country': 'F', 'province': 'prov-France-11'}
# {'id': 'cty-France-9', 'country': 'F', 'province': 'prov-France-5'}
# {'id': 'cty-France-23', 'country': 'F', 'province': 'prov-France-5'}
# {'id': 'cty-France-15', 'country': 'F', 'province': 'prov-France-86'}
# {'id': 'cty-France-24', 'country': 'F', 'province': 'prov-France-86'}
# {'id': 'cty-France-3', 'country': 'F', 'province': 'prov-France-104'}
# {'id': 'cty-France-Nice', 'country': 'F', 'province': 'prov-France-104'}
# {'id': 'cty-France-16', 'country': 'F', 'province': 'prov-France-104'}
# {'id': 'cty-France-27', 'country': 'F', 'province': 'prov-France-104'}
# {'id': 'cty-France-12', 'country': 'F', 'province': 'prov-France-20'}
# {'id': 'cty-France-18', 'country': 'F', 'province': 'prov-France-20'}
# {'id': 'cty-France-34', 'country': 'F', 'province': 'prov-France-30'}
# {'id': 'cty-France-25', 'country': 'F', 'province': 'prov-France-30'}
# {'id': 'cty-France-Nantes', 'country': 'F', 'province': 'prov-France-89'}
# {'id': 'cty-France-21', 'country': 'F', 'province': 'prov-France-89'}
# {'id': 'cty-France-20', 'country': 'F', 'province': 'prov-France-89'}
# {'id': 'cty-France-Strasbourg', 'country': 'F', 'province': 'prov-France-2'}
# {'id': 'cty-France-32', 'country': 'F', 'province': 'prov-France-2'}
# {'id': 'cty-France-28', 'country': 'F', 'province': 'prov-France-2'}
# {'id': 'cty-France-37', 'country': 'F', 'province': 'prov-France-2'}
# {'id': 'cty-France-14', 'country': 'F', 'province': 'prov-France-2'}
# {'id': 'cty-France-35', 'country': 'F', 'province': 'prov-France-50'}
# {'id': 'cty-France-13', 'country': 'F', 'province': 'prov-France-50'}
# {'id': 'cty-France-31', 'country': 'F', 'province': 'prov-France-50'}
# {'id': 'cty-France-19', 'country': 'F', 'province': 'prov-France-25'}
# {'id': 'cty-France-30', 'country': 'F', 'province': 'prov-France-25'}
# {'id': 'cty-France-5', 'country': 'F', 'province': 'prov-France-77'}
# {'id': 'cty-France-10', 'country': 'F', 'province': 'prov-France-77'}
# {'id': 'cty-France-26', 'country': 'F', 'province': 'prov-France-77'}
# {'id': 'cty-France-33', 'country': 'F', 'province': 'prov-France-77'}
# {'id': 'cty-France-Ajaccio', 'country': 'F', 'province': 'prov-France-42'}
# {'id': 'cty-Spain-5', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-34', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-39', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-13', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-16', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-41', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-7', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-27', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-52', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-54', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-57', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-58', 'country': 'E', 'province': 'prov-Spain-2'}
# {'id': 'cty-Spain-6', 'country': 'E', 'province': 'prov-Spain-3'}
# {'id': 'cty-Spain-23', 'country': 'E', 'province': 'prov-Spain-4'}
# {'id': 'cty-Spain-17', 'country': 'E', 'province': 'prov-Spain-4'}
# {'id': 'cty-Spain-12', 'country': 'E', 'province': 'prov-Spain-5'}
# {'id': 'cty-Spain-21', 'country': 'E', 'province': 'prov-Spain-6'}
# {'id': 'cty-Spain-8', 'country': 'E', 'province': 'prov-Spain-6'}
# {'id': 'cty-Spain-55', 'country': 'E', 'province': 'prov-Spain-6'}
# {'id': 'cty-Spain-32', 'country': 'E', 'province': 'prov-Spain-6'}
# {'id': 'cty-Spain-22', 'country': 'E', 'province': 'prov-Spain-7'}
# {'id': 'cty-Spain-48', 'country': 'E', 'province': 'prov-Spain-7'}
# {'id': 'cty-Spain-9', 'country': 'E', 'province': 'prov-Spain-7'}
# {'id': 'cty-Spain-63', 'country': 'E', 'province': 'prov-Spain-7'}
# {'id': 'cty-Spain-25', 'country': 'E', 'province': 'prov-Spain-8'}
# {'id': 'cty-Spain-11', 'country': 'E', 'province': 'prov-Spain-9'}
# {'id': 'cty-Spain-35', 'country': 'E', 'province': 'prov-Spain-9'}
# {'id': 'cty-Spain-40', 'country': 'E', 'province': 'prov-Spain-9'}
# {'id': 'cty-Spain-33', 'country': 'E', 'province': 'prov-Spain-9'}
# {'id': 'cty-Spain-Toledo', 'country': 'E', 'province': 'prov-Spain-10'}
# {'id': 'cty-Spain-44', 'country': 'E', 'province': 'prov-Spain-10'}
# {'id': 'cty-Spain-Barcelona', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-51', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-50', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-61', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-18', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-20', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-28', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-37', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-46', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-56', 'country': 'E', 'province': 'prov-Spain-11'}
# {'id': 'cty-Spain-47', 'country': 'E', 'province': 'prov-Spain-12'}
# {'id': 'cty-Spain-Merida', 'country': 'E', 'province': 'prov-Spain-12'}
# {'id': 'cty-Spain-19', 'country': 'E', 'province': 'prov-Spain-13'}
# {'id': 'cty-Spain-14', 'country': 'E', 'province': 'prov-Spain-13'}
# {'id': 'cty-Spain-53', 'country': 'E', 'province': 'prov-Spain-13'}
# {'id': 'cty-Spain-Santiago-de-Compostela', 'country': 'E', 'province': 'prov-Spain-13'}
# {'id': 'cty-Spain-Madrid', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-24', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-31', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-36', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-38', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-42', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-43', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-59', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-60', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-62', 'country': 'E', 'province': 'prov-Spain-14'}
# {'id': 'cty-Spain-10', 'country': 'E', 'province': 'prov-Spain-15'}
# {'id': 'cty-Spain-30', 'country': 'E', 'province': 'prov-Spain-15'}
# {'id': 'cty-Spain-29', 'country': 'E', 'province': 'prov-Spain-16'}
# {'id': 'cty-Spain-49', 'country': 'E', 'province': 'prov-Spain-17'}
# {'id': 'cty-Spain-Valencia', 'country': 'E', 'province': 'prov-Spain-18'}
# {'id': 'cty-Spain-15', 'country': 'E', 'province': 'prov-Spain-18'}
# {'id': 'cty-Spain-26', 'country': 'E', 'province': 'prov-Spain-18'}
# {'id': 'cty-Spain-45', 'country': 'E', 'province': 'prov-Spain-18'}
# {'id': 'cty-Austria-Eisenstadt', 'country': 'A', 'province': 'prov-Austria-2'}
# {'id': 'cty-Austria-Klagenfurt', 'country': 'A', 'province': 'prov-Austria-3'}
# {'id': 'cty-Austria-Villach', 'country': 'A', 'province': 'prov-Austria-3'}
# {'id': 'cty-Austria-Bregenz', 'country': 'A', 'province': 'prov-Austria-4'}
# {'id': 'cty-Austria-Dornbirn', 'country': 'A', 'province': 'prov-Austria-4'}
# {'id': 'cty-Austria-Vienna', 'country': 'A', 'province': 'prov-Austria-5'}
# {'id': 'cty-Austria-4', 'country': 'A', 'province': 'prov-Austria-6'}
# {'id': 'cty-Austria-Wels', 'country': 'A', 'province': 'prov-Austria-6'}
# {'id': 'cty-Austria-6', 'country': 'A', 'province': 'prov-Austria-7'}
# {'id': 'cty-Austria-Lienz', 'country': 'A', 'province': 'prov-Austria-7'}
# {'id': 'cty-Austria-3', 'country': 'A', 'province': 'prov-Austria-8'}
# {'id': 'cty-Austria-5', 'country': 'A', 'province': 'prov-Austria-9'}
# {'id': 'cty-Austria-St-Polten', 'country': 'A', 'province': 'prov-Austria-10'}
# {'id': 'cty-Czech-2', 'country': 'CZ', 'province': 'prov-Czech-1'}
# {'id': 'cty-Czech-8', 'country': 'CZ', 'province': 'prov-Czech-2'}
# {'id': 'cty-Czech-3', 'country': 'CZ', 'province': 'prov-Czech-3'}
# {'id': 'cty-Czech-Karlovy', 'country': 'CZ', 'province': 'prov-Czech-4'}
# {'id': 'cty-Czech-Jihlava', 'country': 'CZ', 'province': 'prov-Czech-5'}
# {'id': 'cty-Czech-9', 'country': 'CZ', 'province': 'prov-Czech-6'}
# {'id': 'cty-Czech-11', 'country': 'CZ', 'province': 'prov-Czech-7'}
# {'id': 'cty-Czech-4', 'country': 'CZ', 'province': 'prov-Czech-8'}
# {'id': 'cty-Czech-5', 'country': 'CZ', 'province': 'prov-Czech-9'}
# {'id': 'cty-Czech-10', 'country': 'CZ', 'province': 'prov-Czech-10'}
# {'id': 'cty-Czech-7', 'country': 'CZ', 'province': 'prov-Czech-11'}
# {'id': 'cty-Czech-Usti-nad-Labem', 'country': 'CZ', 'province': 'prov-Czech-13'}
# {'id': 'cty-Czech-6', 'country': 'CZ', 'province': 'prov-Czech-14'}
# {'id': 'cty-Germany-9', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-Mannheim', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-24', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-41', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-54', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-66', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-69', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-72', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-77', 'country': 'D', 'province': 'prov-Germany-2'}
# {'id': 'cty-Germany-Munich', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-14', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-30', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-58', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-64', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-74', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-76', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-85', 'country': 'D', 'province': 'prov-Germany-3'}
# {'id': 'cty-Germany-Berlin', 'country': 'D', 'province': 'prov-Germany-4'}
# {'id': 'cty-Germany-55', 'country': 'D', 'province': 'prov-Germany-5'}
# {'id': 'cty-Germany-63', 'country': 'D', 'province': 'prov-Germany-5'}
# {'id': 'cty-Germany-11', 'country': 'D', 'province': 'prov-Germany-6'}
# {'id': 'cty-Germany-57', 'country': 'D', 'province': 'prov-Germany-6'}
# {'id': 'cty-Germany-Hamburg', 'country': 'D', 'province': 'prov-Germany-7'}
# {'id': 'cty-Germany-26', 'country': 'D', 'province': 'prov-Germany-8'}
# {'id': 'cty-Germany-6', 'country': 'D', 'province': 'prov-Germany-8'}
# {'id': 'cty-Germany-40', 'country': 'D', 'province': 'prov-Germany-8'}
# {'id': 'cty-Germany-53', 'country': 'D', 'province': 'prov-Germany-8'}
# {'id': 'cty-Germany-71', 'country': 'D', 'province': 'prov-Germany-8'}
# {'id': 'cty-Germany-68', 'country': 'D', 'province': 'prov-Germany-9'}
# {'id': 'cty-Germany-35', 'country': 'D', 'province': 'prov-Germany-9'}
# {'id': 'cty-Germany-Hannover', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-31', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-47', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-51', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-59', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-61', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-70', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-79', 'country': 'D', 'province': 'prov-Germany-10'}
# {'id': 'cty-Germany-10', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-5', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-7', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-8', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-12', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-17', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-18', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-19', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-21', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-22', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-27', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-29', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-32', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-33', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-36', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-38', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-44', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-45', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-46', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-49', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-50', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-52', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-56', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-60', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-65', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-67', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-73', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-78', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-80', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-81', 'country': 'D', 'province': 'prov-Germany-11'}
# {'id': 'cty-Germany-43', 'country': 'D', 'province': 'prov-Germany-12'}
# {'id': 'cty-Germany-48', 'country': 'D', 'province': 'prov-Germany-12'}
# {'id': 'cty-Germany-75', 'country': 'D', 'province': 'prov-Germany-12'}
# {'id': 'cty-Germany-84', 'country': 'D', 'province': 'prov-Germany-12'}
# {'id': 'cty-Germany-Trier', 'country': 'D', 'province': 'prov-Germany-12'}
# {'id': 'cty-Germany-42', 'country': 'D', 'province': 'prov-Germany-13'}
# {'id': 'cty-Germany-16', 'country': 'D', 'province': 'prov-Germany-14'}
# {'id': 'cty-Germany-15', 'country': 'D', 'province': 'prov-Germany-14'}
# {'id': 'cty-Germany-25', 'country': 'D', 'province': 'prov-Germany-14'}
# {'id': 'cty-Germany-82', 'country': 'D', 'province': 'prov-Germany-14'}
# {'id': 'cty-Germany-28', 'country': 'D', 'province': 'prov-Germany-15'}
# {'id': 'cty-Germany-23', 'country': 'D', 'province': 'prov-Germany-15'}
# {'id': 'cty-Germany-34', 'country': 'D', 'province': 'prov-Germany-16'}
# {'id': 'cty-Germany-37', 'country': 'D', 'province': 'prov-Germany-16'}
# {'id': 'cty-Germany-39', 'country': 'D', 'province': 'prov-Germany-17'}
# {'id': 'cty-Germany-62', 'country': 'D', 'province': 'prov-Germany-17'}
# {'id': 'cty-Germany-83', 'country': 'D', 'province': 'prov-Germany-17'}
# {'id': 'cty-Hungary-6', 'country': 'H', 'province': 'prov-Hungary-2'}
# {'id': 'cty-Hungary-10', 'country': 'H', 'province': 'prov-Hungary-3'}
# {'id': 'cty-Hungary-Bekescaba', 'country': 'H', 'province': 'prov-Hungary-4'}
# {'id': 'cty-Hungary-4', 'country': 'H', 'province': 'prov-Hungary-5'}
# {'id': 'cty-Hungary-5', 'country': 'H', 'province': 'prov-Hungary-6'}
# {'id': 'cty-Hungary-Hodmezovasarhely', 'country': 'H', 'province': 'prov-Hungary-6'}
# {'id': 'cty-Hungary-9', 'country': 'H', 'province': 'prov-Hungary-7'}
# {'id': 'cty-Hungary-7', 'country': 'H', 'province': 'prov-Hungary-8'}
# {'id': 'cty-Hungary-3', 'country': 'H', 'province': 'prov-Hungary-9'}
# {'id': 'cty-Hungary-Eger', 'country': 'H', 'province': 'prov-Hungary-10'}
# {'id': 'cty-Hungary-Tatabanya', 'country': 'H', 'province': 'prov-Hungary-11'}
# {'id': 'cty-Hungary-Salgotarjan', 'country': 'H', 'province': 'prov-Hungary-12'}
# {'id': 'cty-Hungary-Kaposvar', 'country': 'H', 'province': 'prov-Hungary-14'}
# {'id': 'cty-Hungary-8', 'country': 'H', 'province': 'prov-Hungary-15'}
# {'id': 'cty-Hungary-Szolnok', 'country': 'H', 'province': 'prov-Hungary-16'}
# {'id': 'cty-Hungary-Szekszard', 'country': 'H', 'province': 'prov-Hungary-17'}
# {'id': 'cty-Hungary-Szombathely', 'country': 'H', 'province': 'prov-Hungary-18'}
# {'id': 'cty-Hungary-Veszprem', 'country': 'H', 'province': 'prov-Hungary-19'}
# {'id': 'cty-Hungary-Zalaegerszeg', 'country': 'H', 'province': 'prov-Hungary-20'}
# {'id': 'cty-Hungary-Budapest', 'country': 'H', 'province': 'prov-Hungary-21'}
# {'id': 'cty-Italy-44', 'country': 'I', 'province': 'prov-Italy-2'}
# {'id': 'cty-Italy-5', 'country': 'I', 'province': 'prov-Italy-2'}
# {'id': 'cty-Italy-Aosta', 'country': 'I', 'province': 'prov-Italy-9'}
# {'id': 'cty-Italy-36', 'country': 'I', 'province': 'prov-Italy-10'}
# {'id': 'cty-Italy-19', 'country': 'I', 'province': 'prov-Italy-10'}
# {'id': 'cty-Italy-Milan', 'country': 'I', 'province': 'prov-Italy-10'}
# {'id': 'cty-Italy-34', 'country': 'I', 'province': 'prov-Italy-10'}
# {'id': 'cty-Italy-51', 'country': 'I', 'province': 'prov-Italy-20'}
# {'id': 'cty-Italy-49', 'country': 'I', 'province': 'prov-Italy-20'}
# {'id': 'cty-Italy-17', 'country': 'I', 'province': 'prov-Italy-23'}
# {'id': 'cty-Italy-14', 'country': 'I', 'province': 'prov-Italy-23'}
# {'id': 'cty-Italy-39', 'country': 'I', 'province': 'prov-Italy-23'}
# {'id': 'cty-Italy-12', 'country': 'I', 'province': 'prov-Italy-23'}
# {'id': 'cty-Italy-16', 'country': 'I', 'province': 'prov-Italy-31'}
# {'id': 'cty-Italy-46', 'country': 'I', 'province': 'prov-Italy-36'}
# {'id': 'cty-Italy-7', 'country': 'I', 'province': 'prov-Italy-36'}
# {'id': 'cty-Italy-8', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-28', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-38', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-21', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-22', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-43', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-29', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-30', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-31', 'country': 'I', 'province': 'prov-Italy-41'}
# {'id': 'cty-Italy-23', 'country': 'I', 'province': 'prov-Italy-50'}
# {'id': 'cty-Italy-50', 'country': 'I', 'province': 'prov-Italy-50'}
# {'id': 'cty-Italy-9', 'country': 'I', 'province': 'prov-Italy-50'}
# {'id': 'cty-Italy-24', 'country': 'I', 'province': 'prov-Italy-50'}
# {'id': 'cty-Italy-27', 'country': 'I', 'province': 'prov-Italy-60'}
# {'id': 'cty-Italy-37', 'country': 'I', 'province': 'prov-Italy-60'}
# {'id': 'cty-Italy-45', 'country': 'I', 'province': 'prov-Italy-63'}
# {'id': 'cty-Italy-Rome', 'country': 'I', 'province': 'prov-Italy-68'}
# {'id': 'cty-Italy-42', 'country': 'I', 'province': 'prov-Italy-68'}
# {'id': 'cty-Italy-32', 'country': 'I', 'province': 'prov-Italy-74'}
# {'id': 'cty-Italy-LAquila', 'country': 'I', 'province': 'prov-Italy-74'}
# {'id': 'cty-Italy-Campobasso', 'country': 'I', 'province': 'prov-Italy-79'}
# {'id': 'cty-Italy-26', 'country': 'I', 'province': 'prov-Italy-82'}
# {'id': 'cty-Italy-4', 'country': 'I', 'province': 'prov-Italy-82'}
# {'id': 'cty-Italy-47', 'country': 'I', 'province': 'prov-Italy-82'}
# {'id': 'cty-Italy-52', 'country': 'I', 'province': 'prov-Italy-82'}
# {'id': 'cty-Italy-11', 'country': 'I', 'province': 'prov-Italy-88'}
# {'id': 'cty-Italy-25', 'country': 'I', 'province': 'prov-Italy-88'}
# {'id': 'cty-Italy-48', 'country': 'I', 'province': 'prov-Italy-88'}
# {'id': 'cty-Italy-53', 'country': 'I', 'province': 'prov-Italy-88'}
# {'id': 'cty-Italy-15', 'country': 'I', 'province': 'prov-Italy-88'}
# {'id': 'cty-Italy-Potenza', 'country': 'I', 'province': 'prov-Italy-94'}
# {'id': 'cty-Italy-41', 'country': 'I', 'province': 'prov-Italy-97'}
# {'id': 'cty-Italy-40', 'country': 'I', 'province': 'prov-Italy-97'}
# {'id': 'cty-Italy-20', 'country': 'I', 'province': 'prov-Italy-97'}
# {'id': 'cty-Italy-6', 'country': 'I', 'province': 'prov-Italy-101'}
# {'id': 'cty-Italy-13', 'country': 'I', 'province': 'prov-Italy-101'}
# {'id': 'cty-Italy-10', 'country': 'I', 'province': 'prov-Italy-101'}
# {'id': 'cty-Italy-33', 'country': 'I', 'province': 'prov-Italy-101'}
# {'id': 'cty-Italy-18', 'country': 'I', 'province': 'prov-Italy-111'}
# {'id': 'cty-Italy-35', 'country': 'I', 'province': 'prov-Italy-111'}
# {'id': 'cty-Liechtenstein-Vaduz', 'country': 'FL'}
# {'id': 'cty-Slovakia-Bratislava', 'country': 'SK', 'province': 'prov-Slovakia-1'}
# {'id': 'cty-Slovakia-2', 'country': 'SK', 'province': 'prov-Slovakia-2'}
# {'id': 'cty-Slovakia-3', 'country': 'SK', 'province': 'prov-Slovakia-3'}
# {'id': 'cty-Slovakia-4', 'country': 'SK', 'province': 'prov-Slovakia-4'}
# {'id': 'cty-Slovakia-5', 'country': 'SK', 'province': 'prov-Slovakia-5'}
# {'id': 'cty-Slovakia-6', 'country': 'SK', 'province': 'prov-Slovakia-6'}
# {'id': 'cty-Slovakia-7', 'country': 'SK', 'province': 'prov-Slovakia-7'}
# {'id': 'cty-Slovakia-8', 'country': 'SK', 'province': 'prov-Slovakia-8'}
# {'id': 'cty-Slovenia-Ljubljana', 'country': 'SLO'}
# {'id': 'cty-Slovenia-Maribor', 'country': 'SLO'}
# {'id': 'cty-Switzerland-Aarau', 'country': 'CH', 'province': 'prov-Switzerland-2'}
# {'id': 'cty-Switzerland-Herisau', 'country': 'CH', 'province': 'prov-Switzerland-3'}
# {'id': 'cty-Switzerland-Appenzell', 'country': 'CH', 'province': 'prov-Switzerland-4'}
# {'id': 'cty-Switzerland-Liestal', 'country': 'CH', 'province': 'prov-Switzerland-5'}
# {'id': 'cty-Switzerland-3', 'country': 'CH', 'province': 'prov-Switzerland-6'}
# {'id': 'cty-Switzerland-5', 'country': 'CH', 'province': 'prov-Switzerland-7'}
# {'id': 'cty-Switzerland-10', 'country': 'CH', 'province': 'prov-Switzerland-7'}
# {'id': 'cty-Switzerland-Fribourg', 'country': 'CH', 'province': 'prov-Switzerland-8'}
# {'id': 'cty-Switzerland-4', 'country': 'CH', 'province': 'prov-Switzerland-9'}
# {'id': 'cty-Switzerland-Glarus', 'country': 'CH', 'province': 'prov-Switzerland-10'}
# {'id': 'cty-Switzerland-Chur', 'country': 'CH', 'province': 'prov-Switzerland-11'}
# {'id': 'cty-Switzerland-Delemont', 'country': 'CH', 'province': 'prov-Switzerland-12'}
# {'id': 'cty-Switzerland-9', 'country': 'CH', 'province': 'prov-Switzerland-13'}
# {'id': 'cty-Switzerland-Neuchatel', 'country': 'CH', 'province': 'prov-Switzerland-14'}
# {'id': 'cty-Switzerland-Stans', 'country': 'CH', 'province': 'prov-Switzerland-15'}
# {'id': 'cty-Switzerland-Sarnen', 'country': 'CH', 'province': 'prov-Switzerland-16'}
# {'id': 'cty-Switzerland-8', 'country': 'CH', 'province': 'prov-Switzerland-17'}
# {'id': 'cty-Switzerland-Schaffhausen', 'country': 'CH', 'province': 'prov-Switzerland-18'}
# {'id': 'cty-Switzerland-Schwyz', 'country': 'CH', 'province': 'prov-Switzerland-19'}
# {'id': 'cty-Switzerland-Solothurn', 'country': 'CH', 'province': 'prov-Switzerland-20'}
# {'id': 'cty-Switzerland-Frauenfeld', 'country': 'CH', 'province': 'prov-Switzerland-21'}
# {'id': 'cty-Switzerland-Bellinzona', 'country': 'CH', 'province': 'prov-Switzerland-22'}
# {'id': 'cty-Switzerland-Lugano', 'country': 'CH', 'province': 'prov-Switzerland-22'}
# {'id': 'cty-Switzerland-Altdorf', 'country': 'CH', 'province': 'prov-Switzerland-23'}
# {'id': 'cty-Switzerland-Sion', 'country': 'CH', 'province': 'prov-Switzerland-24'}
# {'id': 'cty-Switzerland-6', 'country': 'CH', 'province': 'prov-Switzerland-25'}
# {'id': 'cty-Switzerland-Zug', 'country': 'CH', 'province': 'prov-Switzerland-26'}
# {'id': 'cty-Switzerland-2', 'country': 'CH', 'province': 'prov-Switzerland-27'}
# {'id': 'cty-Switzerland-7', 'country': 'CH', 'province': 'prov-Switzerland-27'}
# {'id': 'cty-Belarus-1', 'country': 'BY', 'province': 'prov-Belarus-1'}
# {'id': 'cty-Belarus-2', 'country': 'BY', 'province': 'prov-Belarus-2'}
# {'id': 'cty-Belarus-3', 'country': 'BY', 'province': 'prov-Belarus-3'}
# {'id': 'cty-Belarus-4', 'country': 'BY', 'province': 'prov-Belarus-4'}
# {'id': 'cty-Belarus-5', 'country': 'BY', 'province': 'prov-Belarus-5'}
# {'id': 'cty-Belarus-6', 'country': 'BY', 'province': 'prov-Belarus-5'}
# {'id': 'cty-Belarus-Minsk', 'country': 'BY', 'province': 'prov-Belarus-7'}
# {'id': 'cty-Latvia-Riga', 'country': 'LV'}
# {'id': 'cty-Lithuania-1', 'country': 'LT'}
# {'id': 'cty-Lithuania-2', 'country': 'LT'}
# {'id': 'cty-Lithuania-3', 'country': 'LT'}
# {'id': 'cty-PL-5', 'country': 'PL', 'province': 'prov-PL-1'}
# {'id': 'cty-PL-41', 'country': 'PL', 'province': 'prov-PL-1'}
# {'id': 'cty-PL-28', 'country': 'PL', 'province': 'prov-PL-1'}
# {'id': 'cty-PL-9', 'country': 'PL', 'province': 'prov-PL-2'}
# {'id': 'cty-PL-21', 'country': 'PL', 'province': 'prov-PL-2'}
# {'id': 'cty-PL-43', 'country': 'PL', 'province': 'prov-PL-2'}
# {'id': 'cty-PL-35', 'country': 'PL', 'province': 'prov-PL-2'}
# {'id': 'cty-PL-11', 'country': 'PL', 'province': 'prov-PL-3'}
# {'id': 'cty-PL-37', 'country': 'PL', 'province': 'prov-PL-4'}
# {'id': 'cty-PL-Gorzow-Wielkopolski', 'country': 'PL', 'province': 'prov-PL-4'}
# {'id': 'cty-PL-3', 'country': 'PL', 'province': 'prov-PL-5'}
# {'id': 'cty-PL-Krakow', 'country': 'PL', 'province': 'prov-PL-6'}
# {'id': 'cty-PL-36', 'country': 'PL', 'province': 'prov-PL-6'}
# {'id': 'cty-PL-Warsaw', 'country': 'PL', 'province': 'prov-PL-7'}
# {'id': 'cty-PL-34', 'country': 'PL', 'province': 'prov-PL-7'}
# {'id': 'cty-PL-17', 'country': 'PL', 'province': 'prov-PL-7'}
# {'id': 'cty-PL-31', 'country': 'PL', 'province': 'prov-PL-8'}
# {'id': 'cty-PL-26', 'country': 'PL', 'province': 'prov-PL-9'}
# {'id': 'cty-PL-12', 'country': 'PL', 'province': 'prov-PL-10'}
# {'id': 'cty-PL-7', 'country': 'PL', 'province': 'prov-PL-11'}
# {'id': 'cty-PL-15', 'country': 'PL', 'province': 'prov-PL-11'}
# {'id': 'cty-PL-10', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-42', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-13', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-29', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-16', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-18', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-20', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-22', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-24', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-27', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-30', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-14', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-33', 'country': 'PL', 'province': 'prov-PL-12'}
# {'id': 'cty-PL-19', 'country': 'PL', 'province': 'prov-PL-13'}
# {'id': 'cty-PL-25', 'country': 'PL', 'province': 'prov-PL-14'}
# {'id': 'cty-PL-32', 'country': 'PL', 'province': 'prov-PL-14'}
# {'id': 'cty-PL-6', 'country': 'PL', 'province': 'prov-PL-15'}
# {'id': 'cty-PL-40', 'country': 'PL', 'province': 'prov-PL-15'}
# {'id': 'cty-PL-8', 'country': 'PL', 'province': 'prov-PL-16'}
# {'id': 'cty-PL-39', 'country': 'PL', 'province': 'prov-PL-16'}
# {'id': 'cty-Ukraine-21', 'country': 'UA', 'province': 'prov-Ukraine-2'}
# {'id': 'cty-Ukraine-20', 'country': 'UA', 'province': 'prov-Ukraine-3'}
# {'id': 'cty-Ukraine-26', 'country': 'UA', 'province': 'prov-Ukraine-4'}
# {'id': 'cty-Ukraine-4', 'country': 'UA', 'province': 'prov-Ukraine-5'}
# {'id': 'cty-Ukraine-9', 'country': 'UA', 'province': 'prov-Ukraine-5'}
# {'id': 'cty-Ukraine-24', 'country': 'UA', 'province': 'prov-Ukraine-5'}
# {'id': 'cty-Ukraine-Nikopol', 'country': 'UA', 'province': 'prov-Ukraine-5'}
# {'id': 'cty-Ukraine-5', 'country': 'UA', 'province': 'prov-Ukraine-6'}
# {'id': 'cty-Ukraine-10', 'country': 'UA', 'province': 'prov-Ukraine-6'}
# {'id': 'cty-Ukraine-13', 'country': 'UA', 'province': 'prov-Ukraine-6'}
# {'id': 'cty-Ukraine-18', 'country': 'UA', 'province': 'prov-Ukraine-6'}
# {'id': 'cty-Ukraine-Kramatorsk', 'country': 'UA', 'province': 'prov-Ukraine-6'}
# {'id': 'cty-Ukraine-30', 'country': 'UA', 'province': 'prov-Ukraine-7'}
# {'id': 'cty-Ukraine-Kharkiv', 'country': 'UA', 'province': 'prov-Ukraine-8'}
# {'id': 'cty-Ukraine-16', 'country': 'UA', 'province': 'prov-Ukraine-9'}
# {'id': 'cty-Ukraine-27', 'country': 'UA', 'province': 'prov-Ukraine-10'}
# {'id': 'cty-Ukraine-Prypjat', 'country': 'UA', 'province': 'prov-Ukraine-11'}
# {'id': 'cty-Ukraine-25', 'country': 'UA', 'province': 'prov-Ukraine-12'}
# {'id': 'cty-Ukraine-12', 'country': 'UA', 'province': 'prov-Ukraine-13'}
# {'id': 'cty-Ukraine-8', 'country': 'UA', 'province': 'prov-Ukraine-14'}
# {'id': 'cty-Ukraine-11', 'country': 'UA', 'province': 'prov-Ukraine-15'}
# {'id': 'cty-Ukraine-Odesa', 'country': 'UA', 'province': 'prov-Ukraine-16'}
# {'id': 'cty-Ukraine-19', 'country': 'UA', 'province': 'prov-Ukraine-17'}
# {'id': 'cty-Ukraine-28', 'country': 'UA', 'province': 'prov-Ukraine-17'}
# {'id': 'cty-Ukraine-29', 'country': 'UA', 'province': 'prov-Ukraine-18'}
# {'id': 'cty-Ukraine-23', 'country': 'UA', 'province': 'prov-Ukraine-19'}
# {'id': 'cty-Ukraine-31', 'country': 'UA', 'province': 'prov-Ukraine-20'}
# {'id': 'cty-Ukraine-14', 'country': 'UA', 'province': 'prov-Ukraine-21'}
# {'id': 'cty-Ukraine-32', 'country': 'UA', 'province': 'prov-Ukraine-22'}
# {'id': 'cty-Ukraine-Uzhhorod', 'country': 'UA', 'province': 'prov-Ukraine-23'}
# {'id': 'cty-Ukraine-7', 'country': 'UA', 'province': 'prov-Ukraine-24'}
# {'id': 'cty-Ukraine-Melitopol', 'country': 'UA', 'province': 'prov-Ukraine-24'}
# {'id': 'cty-Ukraine-22', 'country': 'UA', 'province': 'prov-Ukraine-25'}
# {'id': 'cty-Ukraine-17', 'country': 'UA', 'province': 'prov-Ukraine-27'}
# {'id': 'cty-Ukraine-Kerch', 'country': 'UA', 'province': 'prov-Ukraine-27'}
# {'id': 'cty-Ukraine-Kiev', 'country': 'UA', 'province': 'prov-Ukraine-28'}
# {'id': 'cty-Ukraine-BilaTserkva', 'country': 'UA', 'province': 'prov-Ukraine-28'}
# {'id': 'cty-Ukraine-15', 'country': 'UA', 'province': 'prov-Ukraine-29'}
# {'id': 'cty-Russia-71', 'country': 'R', 'province': 'prov-Russia-3'}
# {'id': 'cty-Russia-85', 'country': 'R', 'province': 'prov-Russia-4'}
# {'id': 'cty-Russia-161', 'country': 'R', 'province': 'prov-Russia-4'}
# {'id': 'cty-Russia-163', 'country': 'R', 'province': 'prov-Russia-4'}
# {'id': 'cty-Russia-Arkhangelsk', 'country': 'R', 'province': 'prov-Russia-5'}
# {'id': 'cty-Russia-80', 'country': 'R', 'province': 'prov-Russia-5'}
# {'id': 'cty-Russia-66', 'country': 'R', 'province': 'prov-Russia-7'}
# {'id': 'cty-Russia-62', 'country': 'R', 'province': 'prov-Russia-7'}
# {'id': 'cty-Russia-47', 'country': 'R', 'province': 'prov-Russia-8'}
# {'id': 'cty-Russia-Kaliningrad', 'country': 'R', 'province': 'prov-Russia-9'}
# {'id': 'cty-Russia-3', 'country': 'R', 'province': 'prov-Russia-10'}
# {'id': 'cty-Russia-83', 'country': 'R', 'province': 'prov-Russia-12'}
# {'id': 'cty-Russia-90', 'country': 'R', 'province': 'prov-Russia-13'}
# {'id': 'cty-Russia-40', 'country': 'R', 'province': 'prov-Russia-14'}
# {'id': 'cty-Russia-57', 'country': 'R', 'province': 'prov-Russia-15'}
# {'id': 'cty-Russia-110', 'country': 'R', 'province': 'prov-Russia-15'}
# {'id': 'cty-Russia-133', 'country': 'R', 'province': 'prov-Russia-15'}
# {'id': 'cty-Russia-36', 'country': 'R', 'province': 'prov-Russia-16'}
# {'id': 'cty-Russia-55', 'country': 'R', 'province': 'prov-Russia-17'}
# {'id': 'cty-Russia-155', 'country': 'R', 'province': 'prov-Russia-17'}
# {'id': 'cty-Russia-70', 'country': 'R', 'province': 'prov-Russia-18'}
# {'id': 'cty-Russia-Moscow', 'country': 'R', 'province': 'prov-Russia-19'}
# {'id': 'cty-Russia-94', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-98', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-Krasnogorsk', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-106', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-116', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-117', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-118', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-121', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-124', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-127', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-130', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-134', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-140', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-157', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-146', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-Koroljow', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-Zhukovsky', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-Pushkino', 'country': 'R', 'province': 'prov-Russia-20'}
# {'id': 'cty-Russia-54', 'country': 'R', 'province': 'prov-Russia-21'}
# {'id': 'cty-Russia-28', 'country': 'R', 'province': 'prov-Russia-22'}
# {'id': 'cty-Russia-52', 'country': 'R', 'province': 'prov-Russia-23'}
# {'id': 'cty-Russia-41', 'country': 'R', 'province': 'prov-Russia-24'}
# {'id': 'cty-Russia-31', 'country': 'R', 'province': 'prov-Russia-25'}
# {'id': 'cty-Russia-119', 'country': 'R', 'province': 'prov-Russia-25'}
# {'id': 'cty-Russia-23', 'country': 'R', 'province': 'prov-Russia-26'}
# {'id': 'cty-Russia-79', 'country': 'R', 'province': 'prov-Russia-26'}
# {'id': 'cty-Russia-78', 'country': 'R', 'province': 'prov-Russia-27'}
# {'id': 'cty-Russia-61', 'country': 'R', 'province': 'prov-Russia-28'}
# {'id': 'cty-Russia-42', 'country': 'R', 'province': 'prov-Russia-29'}
# {'id': 'cty-Russia-136', 'country': 'R', 'province': 'prov-Russia-29'}
# {'id': 'cty-Russia-39', 'country': 'R', 'province': 'prov-Russia-30'}
# {'id': 'cty-Russia-4', 'country': 'R', 'province': 'prov-Russia-31'}
# {'id': 'cty-Russia-69', 'country': 'R', 'province': 'prov-Russia-31'}
# {'id': 'cty-Russia-147', 'country': 'R', 'province': 'prov-Russia-31'}
# {'id': 'cty-Russia-59', 'country': 'R', 'province': 'prov-Russia-32'}
# {'id': 'cty-Russia-95', 'country': 'R', 'province': 'prov-Russia-32'}
# {'id': 'cty-Russia-15', 'country': 'R', 'province': 'prov-Russia-33'}
# {'id': 'cty-Russia-43', 'country': 'R', 'province': 'prov-Russia-34'}
# {'id': 'cty-Russia-37', 'country': 'R', 'province': 'prov-Russia-35'}
# {'id': 'cty-Russia-139', 'country': 'R', 'province': 'prov-Russia-35'}
# {'id': 'cty-Russia-63', 'country': 'R', 'province': 'prov-Russia-36'}
# {'id': 'cty-Russia-Elista', 'country': 'R', 'province': 'prov-Russia-37'}
# {'id': 'cty-Russia-11', 'country': 'R', 'province': 'prov-Russia-38'}
# {'id': 'cty-Russia-32', 'country': 'R', 'province': 'prov-Russia-38'}
# {'id': 'cty-Russia-88', 'country': 'R', 'province': 'prov-Russia-38'}
# {'id': 'cty-Russia-122', 'country': 'R', 'province': 'prov-Russia-38'}
# {'id': 'cty-Russia-35', 'country': 'R', 'province': 'prov-Russia-39'}
# {'id': 'cty-Russia-Volgograd', 'country': 'R', 'province': 'prov-Russia-40'}
# {'id': 'cty-Russia-68', 'country': 'R', 'province': 'prov-Russia-40'}
# {'id': 'cty-Russia-131', 'country': 'R', 'province': 'prov-Russia-40'}
# {'id': 'cty-Russia-29', 'country': 'R', 'province': 'prov-Russia-41'}
# {'id': 'cty-Russia-7', 'country': 'R', 'province': 'prov-Russia-42'}
# {'id': 'cty-Russia-18', 'country': 'R', 'province': 'prov-Russia-42'}
# {'id': 'cty-Russia-103', 'country': 'R', 'province': 'prov-Russia-42'}
# {'id': 'cty-Russia-145', 'country': 'R', 'province': 'prov-Russia-42'}
# {'id': 'cty-Russia-16', 'country': 'R', 'province': 'prov-Russia-43'}
# {'id': 'cty-Russia-91', 'country': 'R', 'province': 'prov-Russia-43'}
# {'id': 'cty-Russia-100', 'country': 'R', 'province': 'prov-Russia-43'}
# {'id': 'cty-Russia-19', 'country': 'R', 'province': 'prov-Russia-44'}
# {'id': 'cty-Russia-125', 'country': 'R', 'province': 'prov-Russia-44'}
# {'id': 'cty-Russia-13', 'country': 'R', 'province': 'prov-Russia-45'}
# {'id': 'cty-Russia-Bataisk', 'country': 'R', 'province': 'prov-Russia-45'}
# {'id': 'cty-Russia-67', 'country': 'R', 'province': 'prov-Russia-45'}
# {'id': 'cty-Russia-84', 'country': 'R', 'province': 'prov-Russia-45'}
# {'id': 'cty-Russia-99', 'country': 'R', 'province': 'prov-Russia-45'}
# {'id': 'cty-Russia-102', 'country': 'R', 'province': 'prov-Russia-45'}
# {'id': 'cty-Russia-159', 'country': 'R', 'province': 'prov-Russia-45'}
# {'id': 'cty-Russia-9', 'country': 'R', 'province': 'prov-Russia-46'}
# {'id': 'cty-Russia-75', 'country': 'R', 'province': 'prov-Russia-46'}
# {'id': 'cty-Russia-115', 'country': 'R', 'province': 'prov-Russia-46'}
# {'id': 'cty-Russia-149', 'country': 'R', 'province': 'prov-Russia-46'}
# {'id': 'cty-Russia-20', 'country': 'R', 'province': 'prov-Russia-47'}
# {'id': 'cty-Russia-153', 'country': 'R', 'province': 'prov-Russia-47'}
# {'id': 'cty-Russia-30', 'country': 'R', 'province': 'prov-Russia-48'}
# {'id': 'cty-Russia-72', 'country': 'R', 'province': 'prov-Russia-48'}
# {'id': 'cty-Russia-12', 'country': 'R', 'province': 'prov-Russia-49'}
# {'id': 'cty-Russia-101', 'country': 'R', 'province': 'prov-Russia-49'}
# {'id': 'cty-Russia-107', 'country': 'R', 'province': 'prov-Russia-52'}
# {'id': 'cty-Russia-58', 'country': 'R', 'province': 'prov-Russia-53'}
# {'id': 'cty-Russia-Derbent', 'country': 'R', 'province': 'prov-Russia-53'}
# {'id': 'cty-Russia-Kaspijsk', 'country': 'R', 'province': 'prov-Russia-53'}
# {'id': 'cty-Russia-Khasavyurt', 'country': 'R', 'province': 'prov-Russia-53'}
# {'id': 'cty-Russia-Nazran', 'country': 'R', 'province': 'prov-Russia-54'}
# {'id': 'cty-Russia-81', 'country': 'R', 'province': 'prov-Russia-55'}
# {'id': 'cty-Russia-141', 'country': 'R', 'province': 'prov-Russia-56'}
# {'id': 'cty-Russia-64', 'country': 'R', 'province': 'prov-Russia-57'}
# {'id': 'cty-Russia-50', 'country': 'R', 'province': 'prov-Russia-58'}
# {'id': 'cty-Russia-21', 'country': 'R', 'province': 'prov-Russia-59'}
# {'id': 'cty-Russia-53', 'country': 'R', 'province': 'prov-Russia-59'}
# {'id': 'cty-Russia-93', 'country': 'R', 'province': 'prov-Russia-59'}
# {'id': 'cty-Russia-108', 'country': 'R', 'province': 'prov-Russia-59'}
# {'id': 'cty-Russia-56', 'country': 'R', 'province': 'prov-Russia-60'}
# {'id': 'cty-Russia-128', 'country': 'R', 'province': 'prov-Russia-60'}
# {'id': 'cty-Russia-129', 'country': 'R', 'province': 'prov-Russia-60'}
# {'id': 'cty-Russia-138', 'country': 'R', 'province': 'prov-Russia-60'}
# {'id': 'cty-Russia-Jessentuki', 'country': 'R', 'province': 'prov-Russia-60'}
# {'id': 'cty-Russia-142', 'country': 'R', 'province': 'prov-Russia-60'}
# {'id': 'cty-Russia-51', 'country': 'R', 'province': 'prov-Russia-61'}
# {'id': 'cty-Russia-6', 'country': 'R', 'province': 'prov-Russia-62'}
# {'id': 'cty-Russia-46', 'country': 'R', 'province': 'prov-Russia-62'}
# {'id': 'cty-Russia-96', 'country': 'R', 'province': 'prov-Russia-62'}
# {'id': 'cty-Russia-123', 'country': 'R', 'province': 'prov-Russia-62'}
# {'id': 'cty-Russia-10', 'country': 'R', 'province': 'prov-Russia-63'}
# {'id': 'cty-Russia-44', 'country': 'R', 'province': 'prov-Russia-63'}
# {'id': 'cty-Russia-92', 'country': 'R', 'province': 'prov-Russia-63'}
# {'id': 'cty-Russia-105', 'country': 'R', 'province': 'prov-Russia-63'}
# {'id': 'cty-Russia-Kopejsk', 'country': 'R', 'province': 'prov-Russia-63'}
# {'id': 'cty-Russia-Gorno-Altaysk', 'country': 'R', 'province': 'prov-Russia-64'}
# {'id': 'cty-Russia-25', 'country': 'R', 'province': 'prov-Russia-65'}
# {'id': 'cty-Russia-86', 'country': 'R', 'province': 'prov-Russia-65'}
# {'id': 'cty-Russia-104', 'country': 'R', 'province': 'prov-Russia-65'}
# {'id': 'cty-Russia-33', 'country': 'R', 'province': 'prov-Russia-66'}
# {'id': 'cty-Russia-27', 'country': 'R', 'province': 'prov-Russia-66'}
# {'id': 'cty-Russia-77', 'country': 'R', 'province': 'prov-Russia-66'}
# {'id': 'cty-Russia-5', 'country': 'R', 'province': 'prov-Russia-67'}
# {'id': 'cty-Russia-8', 'country': 'R', 'province': 'prov-Russia-68'}
# {'id': 'cty-Russia-38', 'country': 'R', 'province': 'prov-Russia-69'}
# {'id': 'cty-Russia-150', 'country': 'R', 'province': 'prov-Russia-69'}
# {'id': 'cty-Russia-34', 'country': 'R', 'province': 'prov-Russia-70'}
# {'id': 'cty-Russia-49', 'country': 'R', 'province': 'prov-Russia-72'}
# {'id': 'cty-Russia-Kyzyl', 'country': 'R', 'province': 'prov-Russia-73'}
# {'id': 'cty-Russia-112', 'country': 'R', 'province': 'prov-Russia-74'}
# {'id': 'cty-Russia-Krasnoyarsk', 'country': 'R', 'province': 'prov-Russia-75'}
# {'id': 'cty-Russia-114', 'country': 'R', 'province': 'prov-Russia-75'}
# {'id': 'cty-Russia-135', 'country': 'R', 'province': 'prov-Russia-75'}
# {'id': 'cty-Russia-26', 'country': 'R', 'province': 'prov-Russia-77'}
# {'id': 'cty-Russia-73', 'country': 'R', 'province': 'prov-Russia-77'}
# {'id': 'cty-Russia-76', 'country': 'R', 'province': 'prov-Russia-77'}
# {'id': 'cty-Russia-60', 'country': 'R', 'province': 'prov-Russia-79'}
# {'id': 'cty-Russia-97', 'country': 'R', 'province': 'prov-Russia-81'}
# {'id': 'cty-Russia-Birobidzhan', 'country': 'R', 'province': 'prov-Russia-82'}
# {'id': 'cty-Russia-Anadyr', 'country': 'R', 'province': 'prov-Russia-83'}
# {'id': 'cty-Russia-Vladivostok', 'country': 'R', 'province': 'prov-Russia-84'}
# {'id': 'cty-Russia-109', 'country': 'R', 'province': 'prov-Russia-84'}
# {'id': 'cty-Russia-111', 'country': 'R', 'province': 'prov-Russia-84'}
# {'id': 'cty-Russia-24', 'country': 'R', 'province': 'prov-Russia-85'}
# {'id': 'cty-Russia-65', 'country': 'R', 'province': 'prov-Russia-85'}
# {'id': 'cty-Russia-87', 'country': 'R', 'province': 'prov-Russia-86'}
# {'id': 'cty-Russia-89', 'country': 'R', 'province': 'prov-Russia-87'}
# {'id': 'cty-Russia-132', 'country': 'R', 'province': 'prov-Russia-89'}
# {'id': 'cty-Russia-Okhotsk', 'country': 'R', 'province': 'prov-Russia-89'}
# {'id': 'cty-Russia-113', 'country': 'R', 'province': 'prov-Russia-90'}
# {'id': 'cty-Russia-KhantyMansijsk', 'country': 'R', 'province': 'prov-Russia-91'}
# {'id': 'cty-Russia-74', 'country': 'R', 'province': 'prov-Russia-91'}
# {'id': 'cty-Russia-82', 'country': 'R', 'province': 'prov-Russia-91'}
# {'id': 'cty-Russia-Neftejugansk', 'country': 'R', 'province': 'prov-Russia-91'}
# {'id': 'cty-Russia-Salekhard', 'country': 'R', 'province': 'prov-Russia-92'}
# {'id': 'cty-Russia-Nojabrsk', 'country': 'R', 'province': 'prov-Russia-92'}
# {'id': 'cty-Russia-NovyUrengoy', 'country': 'R', 'province': 'prov-Russia-92'}
# {'id': 'cty-Belgium-Brussels', 'country': 'B', 'province': 'prov-Belgium-1'}
# {'id': 'cty-Belgium-Schaarbeek', 'country': 'B', 'province': 'prov-Belgium-1'}
# {'id': 'cty-Belgium-Molenbeek', 'country': 'B', 'province': 'prov-Belgium-1'}
# {'id': 'cty-Belgium-Anderlecht', 'country': 'B', 'province': 'prov-Belgium-1'}
# {'id': 'cty-Belgium-3-0', 'country': 'B', 'province': 'prov-Belgium-2'}
# {'id': 'cty-Belgium-4-0', 'country': 'B', 'province': 'prov-Belgium-4'}
# {'id': 'cty-Belgium-5-0', 'country': 'B', 'province': 'prov-Belgium-5'}
# {'id': 'cty-Belgium-Mons', 'country': 'B', 'province': 'prov-Belgium-5'}
# {'id': 'cty-Belgium-6-0', 'country': 'B', 'province': 'prov-Belgium-6'}
# {'id': 'cty-Belgium-Hasselt', 'country': 'B', 'province': 'prov-Belgium-7'}
# {'id': 'cty-Belgium-Arlon', 'country': 'B', 'province': 'prov-Belgium-8'}
# {'id': 'cty-Belgium-8-0', 'country': 'B', 'province': 'prov-Belgium-9'}
# {'id': 'cty-Belgium-7-0', 'country': 'B', 'province': 'prov-Belgium-10'}
# {'id': 'cty-Belgium-Wavre', 'country': 'B', 'province': 'prov-Belgium-11'}
# {'id': 'cty-Belgium-Leuven', 'country': 'B', 'province': 'prov-Belgium-12'}
# {'id': 'cty-Luxembourg-Luxembourg', 'country': 'L'}
# {'id': 'cty-Netherlands-14', 'country': 'NL', 'province': 'prov-Netherlands-2'}
# {'id': 'cty-Netherlands-Leeuwarden', 'country': 'NL', 'province': 'prov-Netherlands-3'}
# {'id': 'cty-Netherlands-Assen', 'country': 'NL', 'province': 'prov-Netherlands-4'}
# {'id': 'cty-Netherlands-9', 'country': 'NL', 'province': 'prov-Netherlands-5'}
# {'id': 'cty-Netherlands-Zwolle', 'country': 'NL', 'province': 'prov-Netherlands-5'}
# {'id': 'cty-Netherlands-Lelystad', 'country': 'NL', 'province': 'prov-Netherlands-6'}
# {'id': 'cty-Netherlands-Almere', 'country': 'NL', 'province': 'prov-Netherlands-6'}
# {'id': 'cty-Netherlands-7', 'country': 'NL', 'province': 'prov-Netherlands-7'}
# {'id': 'cty-Netherlands-10', 'country': 'NL', 'province': 'prov-Netherlands-7'}
# {'id': 'cty-Netherlands-Apeldoorn', 'country': 'NL', 'province': 'prov-Netherlands-7'}
# {'id': 'cty-Netherlands-5', 'country': 'NL', 'province': 'prov-Netherlands-8'}
# {'id': 'cty-Netherlands-Amersfoort', 'country': 'NL', 'province': 'prov-Netherlands-8'}
# {'id': 'cty-Netherlands-Amsterdam', 'country': 'NL', 'province': 'prov-Netherlands-9'}
# {'id': 'cty-Netherlands-13', 'country': 'NL', 'province': 'prov-Netherlands-9'}
# {'id': 'cty-Netherlands-20', 'country': 'NL', 'province': 'prov-Netherlands-9'}
# {'id': 'cty-Netherlands-22', 'country': 'NL', 'province': 'prov-Netherlands-9'}
# {'id': 'cty-Netherlands-4', 'country': 'NL', 'province': 'prov-Netherlands-10'}
# {'id': 'cty-Netherlands-3', 'country': 'NL', 'province': 'prov-Netherlands-10'}
# {'id': 'cty-Netherlands-12', 'country': 'NL', 'province': 'prov-Netherlands-10'}
# {'id': 'cty-Netherlands-16', 'country': 'NL', 'province': 'prov-Netherlands-10'}
# {'id': 'cty-Netherlands-Middelburg', 'country': 'NL', 'province': 'prov-Netherlands-11'}
# {'id': 'cty-Netherlands-15', 'country': 'NL', 'province': 'prov-Netherlands-12'}
# {'id': 'cty-Netherlands-6', 'country': 'NL', 'province': 'prov-Netherlands-12'}
# {'id': 'cty-Netherlands-11', 'country': 'NL', 'province': 'prov-Netherlands-12'}
# {'id': 'cty-Netherlands-18', 'country': 'NL', 'province': 'prov-Netherlands-12'}
# {'id': 'cty-Netherlands-19', 'country': 'NL', 'province': 'prov-Netherlands-13'}
# {'id': 'cty-Netherlands-8', 'country': 'NL', 'province': 'prov-Netherlands-13'}
# {'id': 'cty-Netherlands-17', 'country': 'NL', 'province': 'prov-Netherlands-13'}
# {'id': 'cty-BIH-1', 'country': 'BIH', 'province': 'prov-BIH-1'}
# {'id': 'cty-BIH-4', 'country': 'BIH', 'province': 'prov-BIH-1'}
# {'id': 'cty-BIH-5', 'country': 'BIH', 'province': 'prov-BIH-1'}
# ...
# {'id': 'cty-WAN-22', 'country': 'WAN', 'province': 'prov-WAN-22'}
# {'id': 'cty-WAN-23', 'country': 'WAN', 'province': 'prov-WAN-23'}
# {'id': 'cty-WAN-58', 'country': 'WAN', 'province': 'prov-WAN-23'}
# {'id': 'cty-WAN-24', 'country': 'WAN', 'province': 'prov-WAN-24'}
# {'id': 'cty-WAN-25', 'country': 'WAN', 'province': 'prov-WAN-25'}
# {'id': 'cty-WAN-59', 'country': 'WAN', 'province': 'prov-WAN-25'}
# {'id': 'cty-WAN-26', 'country': 'WAN', 'province': 'prov-WAN-26'}
# {'id': 'cty-WAN-27', 'country': 'WAN', 'province': 'prov-WAN-27'}
# {'id': 'cty-WAN-55', 'country': 'WAN', 'province': 'prov-WAN-27'}
# {'id': 'cty-WAN-28', 'country': 'WAN', 'province': 'prov-WAN-28'}
# {'id': 'cty-WAN-51', 'country': 'WAN', 'province': 'prov-WAN-28'}
# {'id': 'cty-WAN-29', 'country': 'WAN', 'province': 'prov-WAN-29'}
# {'id': 'cty-WAN-39', 'country': 'WAN', 'province': 'prov-WAN-29'}
# {'id': 'cty-WAN-50', 'country': 'WAN', 'province': 'prov-WAN-29'}
# {'id': 'cty-WAN-53', 'country': 'WAN', 'province': 'prov-WAN-29'}
# {'id': 'cty-WAN-30', 'country': 'WAN', 'province': 'prov-WAN-30'}
# {'id': 'cty-WAN-43', 'country': 'WAN', 'province': 'prov-WAN-30'}
# {'id': 'cty-WAN-45', 'country': 'WAN', 'province': 'prov-WAN-30'}
# {'id': 'cty-WAN-47', 'country': 'WAN', 'province': 'prov-WAN-30'}
# {'id': 'cty-WAN-56', 'country': 'WAN', 'province': 'prov-WAN-30'}
# {'id': 'cty-WAN-31', 'country': 'WAN', 'province': 'prov-WAN-31'}
# {'id': 'cty-WAN-40', 'country': 'WAN', 'province': 'prov-WAN-31'}
# {'id': 'cty-WAN-41', 'country': 'WAN', 'province': 'prov-WAN-31'}
# {'id': 'cty-WAN-48', 'country': 'WAN', 'province': 'prov-WAN-31'}
# {'id': 'cty-WAN-32', 'country': 'WAN', 'province': 'prov-WAN-32'}
# {'id': 'cty-WAN-33', 'country': 'WAN', 'province': 'prov-WAN-33'}
# {'id': 'cty-WAN-34', 'country': 'WAN', 'province': 'prov-WAN-34'}
# {'id': 'cty-WAN-35', 'country': 'WAN', 'province': 'prov-WAN-35'}
# {'id': 'cty-WAN-36', 'country': 'WAN', 'province': 'prov-WAN-36'}
# {'id': 'cty-WAN-37', 'country': 'WAN', 'province': 'prov-WAN-37'}
# {'id': 'cty-Togo-Lome', 'country': 'RT'}
# {'id': 'cty-Botswana-Gaborone', 'country': 'RB'}
# {'id': 'cty-Botswana-Francistown', 'country': 'RB'}
# {'id': 'cty-South-Africa-7', 'country': 'RSA', 'province': 'prov-South-Africa-2'}
# {'id': 'cty-South-Africa-28', 'country': 'RSA', 'province': 'prov-South-Africa-2'}
# {'id': 'cty-South-Africa-Bisho', 'country': 'RSA', 'province': 'prov-South-Africa-2'}
# {'id': 'cty-South-Africa-21', 'country': 'RSA', 'province': 'prov-South-Africa-3'}
# {'id': 'cty-South-Africa-6', 'country': 'RSA', 'province': 'prov-South-Africa-4'}
# {'id': 'cty-South-Africa-4', 'country': 'RSA', 'province': 'prov-South-Africa-4'}
# {'id': 'cty-South-Africa-11', 'country': 'RSA', 'province': 'prov-South-Africa-4'}
# {'id': 'cty-South-Africa-25', 'country': 'RSA', 'province': 'prov-South-Africa-4'}
# {'id': 'cty-South-Africa-26', 'country': 'RSA', 'province': 'prov-South-Africa-4'}
# {'id': 'cty-South-Africa-16', 'country': 'RSA', 'province': 'prov-South-Africa-5'}
# {'id': 'cty-South-Africa-3', 'country': 'RSA', 'province': 'prov-South-Africa-5'}
# {'id': 'cty-South-Africa-Nelspruit', 'country': 'RSA', 'province': 'prov-South-Africa-6'}
# {'id': 'cty-South-Africa-Kimberley', 'country': 'RSA', 'province': 'prov-South-Africa-7'}
# {'id': 'cty-South-Africa-Pietersburg', 'country': 'RSA', 'province': 'prov-South-Africa-8'}
# {'id': 'cty-South-Africa-Mmabatho', 'country': 'RSA', 'province': 'prov-South-Africa-9'}
# {'id': 'cty-South-Africa-2', 'country': 'RSA', 'province': 'prov-South-Africa-10'}
# {'id': 'cty-Zimbabwe-1', 'country': 'ZW'}
# {'id': 'cty-Zimbabwe-2', 'country': 'ZW'}
# {'id': 'cty-Zimbabwe-3', 'country': 'ZW'}
# {'id': 'cty-CI-1', 'country': 'CI', 'province': 'prov-CI-1'}
# {'id': 'cty-CI-2', 'country': 'CI', 'province': 'prov-CI-2'}
# {'id': 'cty-CI-3', 'country': 'CI', 'province': 'prov-CI-3'}
# {'id': 'cty-CI-4', 'country': 'CI', 'province': 'prov-CI-4'}
# {'id': 'cty-CI-5', 'country': 'CI', 'province': 'prov-CI-5'}
# {'id': 'cty-CI-6', 'country': 'CI', 'province': 'prov-CI-6'}
# {'id': 'cty-CI-7', 'country': 'CI', 'province': 'prov-CI-7'}
# {'id': 'cty-CI-Dabou', 'country': 'CI', 'province': 'prov-CI-8'}
# {'id': 'cty-CI-10', 'country': 'CI', 'province': 'prov-CI-10'}
# {'id': 'cty-CI-12', 'country': 'CI', 'province': 'prov-CI-12'}
# {'id': 'cty-CI-14', 'country': 'CI', 'province': 'prov-CI-14'}
# {'id': 'cty-CI-17', 'country': 'CI', 'province': 'prov-CI-17'}
# {'id': 'cty-CI-18', 'country': 'CI', 'province': 'prov-CI-18'}
# {'id': 'cty-CI-19', 'country': 'CI', 'province': 'prov-CI-19'}
# {'id': 'cty-GH-1', 'country': 'GH', 'province': 'prov-GH-1'}
# {'id': 'cty-GH-Obuasi', 'country': 'GH', 'province': 'prov-GH-1'}
# {'id': 'cty-GH-2', 'country': 'GH', 'province': 'prov-GH-2'}
# {'id': 'cty-GH-3', 'country': 'GH', 'province': 'prov-GH-3'}
# {'id': 'cty-GH-4', 'country': 'GH', 'province': 'prov-GH-4'}
# {'id': 'cty-GH-5', 'country': 'GH', 'province': 'prov-GH-5'}
# {'id': 'cty-GH-11', 'country': 'GH', 'province': 'prov-GH-5'}
# {'id': 'cty-GH-Ashaiman', 'country': 'GH', 'province': 'prov-GH-5'}
# {'id': 'cty-GH-6', 'country': 'GH', 'province': 'prov-GH-6'}
# {'id': 'cty-GH-7', 'country': 'GH', 'province': 'prov-GH-7'}
# {'id': 'cty-GH-8', 'country': 'GH', 'province': 'prov-GH-8'}
# {'id': 'cty-GH-9', 'country': 'GH', 'province': 'prov-GH-9'}
# {'id': 'cty-GH-10', 'country': 'GH', 'province': 'prov-GH-10'}
# {'id': 'cty-Burundi-Bujumbura', 'country': 'BI'}
# {'id': 'cty-Burundi-Gitega', 'country': 'BI'}
# {'id': 'cty-Rwanda-Kigali', 'country': 'RWA'}
# {'id': 'cty-Tanzania-4', 'country': 'EAT', 'province': 'prov-Tanzania-2'}
# {'id': 'cty-Tanzania-8', 'country': 'EAT', 'province': 'prov-Tanzania-3'}
# {'id': 'cty-Tanzania-Moshi', 'country': 'EAT', 'province': 'prov-Tanzania-4'}
# {'id': 'cty-Tanzania-5', 'country': 'EAT', 'province': 'prov-Tanzania-5'}
# {'id': 'cty-Tanzania-9', 'country': 'EAT', 'province': 'prov-Tanzania-6'}
# {'id': 'cty-Tanzania-Dar-es-Salaam', 'country': 'EAT', 'province': 'prov-Tanzania-8'}
# {'id': 'cty-Tanzania-Lindi', 'country': 'EAT', 'province': 'prov-Tanzania-9'}
# {'id': 'cty-Tanzania-Mtwara-Mikandani', 'country': 'EAT', 'province': 'prov-Tanzania-10'}
# {'id': 'cty-Tanzania-Songea', 'country': 'EAT', 'province': 'prov-Tanzania-11'}
# {'id': 'cty-Tanzania-Iringa', 'country': 'EAT', 'province': 'prov-Tanzania-12'}
# {'id': 'cty-Tanzania-7', 'country': 'EAT', 'province': 'prov-Tanzania-13'}
# {'id': 'cty-Tanzania-Singida', 'country': 'EAT', 'province': 'prov-Tanzania-14'}
# {'id': 'cty-Tanzania-Tabora', 'country': 'EAT', 'province': 'prov-Tanzania-15'}
# {'id': 'cty-Tanzania-Sumbawanga', 'country': 'EAT', 'province': 'prov-Tanzania-16'}
# {'id': 'cty-Tanzania-Kigoma-Ujiji', 'country': 'EAT', 'province': 'prov-Tanzania-17'}
# {'id': 'cty-Tanzania-10', 'country': 'EAT', 'province': 'prov-Tanzania-18'}
# {'id': 'cty-Tanzania-Bukoba', 'country': 'EAT', 'province': 'prov-Tanzania-19'}
# {'id': 'cty-Tanzania-3', 'country': 'EAT', 'province': 'prov-Tanzania-20'}
# {'id': 'cty-Tanzania-Musoma', 'country': 'EAT', 'province': 'prov-Tanzania-21'}
# {'id': 'cty-Tanzania-Mkokotoni', 'country': 'EAT', 'province': 'prov-Tanzania-22'}
# {'id': 'cty-Tanzania-Koani', 'country': 'EAT', 'province': 'prov-Tanzania-23'}
# {'id': 'cty-Tanzania-6', 'country': 'EAT', 'province': 'prov-Tanzania-24'}
# {'id': 'cty-Tanzania-Wete', 'country': 'EAT', 'province': 'prov-Tanzania-25'}
# {'id': 'cty-Tanzania-Chake-Chake', 'country': 'EAT', 'province': 'prov-Tanzania-26'}
# {'id': 'cty-Tanzania-Babati', 'country': 'EAT', 'province': 'prov-Tanzania-27'}
# {'id': 'cty-Tanzania-Njombe', 'country': 'EAT', 'province': 'prov-Tanzania-28'}
# {'id': 'cty-Tanzania-Mpanda', 'country': 'EAT', 'province': 'prov-Tanzania-29'}
# {'id': 'cty-Tanzania-Bariadi', 'country': 'EAT', 'province': 'prov-Tanzania-30'}
# {'id': 'cty-Tanzania-Geita', 'country': 'EAT', 'province': 'prov-Tanzania-31'}
# {'id': 'cty-Cameroon-Ngaoundere', 'country': 'CAM', 'province': 'prov-Cameroon-2'}
# {'id': 'cty-Cameroon-3', 'country': 'CAM', 'province': 'prov-Cameroon-3'}
# {'id': 'cty-Cameroon-Bertoua', 'country': 'CAM', 'province': 'prov-Cameroon-4'}
# {'id': 'cty-Cameroon-5', 'country': 'CAM', 'province': 'prov-Cameroon-5'}
# {'id': 'cty-Cameroon-2', 'country': 'CAM', 'province': 'prov-Cameroon-6'}
# {'id': 'cty-Cameroon-4', 'country': 'CAM', 'province': 'prov-Cameroon-7'}
# {'id': 'cty-Cameroon-6', 'country': 'CAM', 'province': 'prov-Cameroon-8'}
# {'id': 'cty-Cameroon-7', 'country': 'CAM', 'province': 'prov-Cameroon-9'}
# {'id': 'cty-Cameroon-Ebolowa', 'country': 'CAM', 'province': 'prov-Cameroon-10'}
# {'id': 'cty-Cameroon-Buea', 'country': 'CAM', 'province': 'prov-Cameroon-11'}
# {'id': 'cty-Central-African-Republic-Bangui', 'country': 'RCA'}
# {'id': 'cty-Central-African-Republic-Bimbo', 'country': 'RCA'}
# {'id': 'cty-Chad-NDjamena', 'country': 'TCH'}
# {'id': 'cty-Equatorial-Guinea-Malabo', 'country': 'GQ', 'province': 'prov-GQ-1'}
# {'id': 'cty-Equatorial-Guinea-Bata', 'country': 'GQ', 'province': 'prov-GQ-2'}
# {'id': 'cty-Gabon-Libreville', 'country': 'G'}
# {'id': 'cty-Gabon-PortGentil', 'country': 'G'}
# {'id': 'cty-Gabon-Franceville', 'country': 'G'}
# {'id': 'cty-Cape-Verde-Praia', 'country': 'CV'}
# {'id': 'cty-Sudan-5', 'country': 'SUD', 'province': 'prov-SUD-1'}
# {'id': 'cty-Sudan-9', 'country': 'SUD', 'province': 'prov-SUD-2'}
# {'id': 'cty-Sudan-Khartoum', 'country': 'SUD', 'province': 'prov-SUD-3'}
# {'id': 'cty-Sudan-2', 'country': 'SUD', 'province': 'prov-SUD-3'}
# {'id': 'cty-Sudan-4', 'country': 'SUD', 'province': 'prov-SUD-3'}
# {'id': 'cty-Sudan-10', 'country': 'SUD', 'province': 'prov-SUD-4'}
# {'id': 'cty-Sudan-23', 'country': 'SUD', 'province': 'prov-SUD-4'}
# {'id': 'cty-Sudan-24', 'country': 'SUD', 'province': 'prov-SUD-4'}
# {'id': 'cty-Sudan-13', 'country': 'SUD', 'province': 'prov-SUD-6'}
# {'id': 'cty-Sudan-14', 'country': 'SUD', 'province': 'prov-SUD-7'}
# {'id': 'cty-Sudan-15', 'country': 'SUD', 'province': 'prov-SUD-8'}
# {'id': 'cty-Sudan-16', 'country': 'SUD', 'province': 'prov-SUD-9'}
# {'id': 'cty-Sudan-7', 'country': 'SUD', 'province': 'prov-SUD-10'}
# {'id': 'cty-Sudan-17', 'country': 'SUD', 'province': 'prov-SUD-11'}
# {'id': 'cty-Sudan-6', 'country': 'SUD', 'province': 'prov-SUD-12'}
# {'id': 'cty-Sudan-18', 'country': 'SUD', 'province': 'prov-SUD-13'}
# {'id': 'cty-Sudan-22', 'country': 'SUD', 'province': 'prov-SUD-13'}
# {'id': 'cty-Sudan-19', 'country': 'SUD', 'province': 'prov-SUD-14'}
# {'id': 'cty-Sudan-11', 'country': 'SUD', 'province': 'prov-SUD-15'}
# {'id': 'cty-Sudan-8', 'country': 'SUD', 'province': 'prov-SUD-16'}
# {'id': 'cty-Sudan-20', 'country': 'SUD', 'province': 'prov-SUD-17'}
# {'id': 'cty-Sudan-21', 'country': 'SUD', 'province': 'prov-SUD-18'}
# {'id': 'cty-SouthSudan-Juba', 'country': 'SSD'}
# {'id': 'cty-Comoros-Moroni', 'country': 'COM'}
# {'id': 'cty-Guinea-Conakry', 'country': 'RG'}
# {'id': 'cty-Guinea-NZerekore', 'country': 'RG'}
# {'id': 'cty-Liberia-Monrovia', 'country': 'LB'}
# {'id': 'cty-Djibouti-Djibouti', 'country': 'DJI'}
# {'id': 'cty-Eritrea-Asmara', 'country': 'ER'}
# {'id': 'cty-ETH-1', 'country': 'ETH', 'province': 'prov-ETH-1'}
# {'id': 'cty-ETH-2', 'country': 'ETH', 'province': 'prov-ETH-2'}
# {'id': 'cty-ETH-3', 'country': 'ETH', 'province': 'prov-ETH-3'}
# {'id': 'cty-ETH-12', 'country': 'ETH', 'province': 'prov-ETH-3'}
# {'id': 'cty-ETH-15', 'country': 'ETH', 'province': 'prov-ETH-3'}
# {'id': 'cty-ETH-4', 'country': 'ETH', 'province': 'prov-ETH-4'}
# {'id': 'cty-ETH-5', 'country': 'ETH', 'province': 'prov-ETH-5'}
# {'id': 'cty-ETH-6', 'country': 'ETH', 'province': 'prov-ETH-6'}
# {'id': 'cty-ETH-7', 'country': 'ETH', 'province': 'prov-ETH-7'}
# {'id': 'cty-ETH-13', 'country': 'ETH', 'province': 'prov-ETH-13'}
# {'id': 'cty-ETH-14', 'country': 'ETH', 'province': 'prov-ETH-13'}
# {'id': 'cty-ETH-16', 'country': 'ETH', 'province': 'prov-ETH-13'}
# {'id': 'cty-ETH-9', 'country': 'ETH', 'province': 'prov-ETH-9'}
# {'id': 'cty-ETH-10', 'country': 'ETH', 'province': 'prov-ETH-10'}
# {'id': 'cty-ETH-11', 'country': 'ETH', 'province': 'prov-ETH-11'}
# {'id': 'cty-Somalia-Mogadishu', 'country': 'SP'}
# {'id': 'cty-Kenya-3', 'country': 'EAK'}
# {'id': 'cty-Kenya-21', 'country': 'EAK'}
# {'id': 'cty-Kenya-12', 'country': 'EAK'}
# {'id': 'cty-Kenya-Nairobi', 'country': 'EAK'}
# {'id': 'cty-Kenya-4', 'country': 'EAK'}
# {'id': 'cty-Kenya-5', 'country': 'EAK'}
# {'id': 'cty-Kenya-16', 'country': 'EAK'}
# {'id': 'cty-Gambia-Banjul', 'country': 'WAG'}
# {'id': 'cty-Senegal-Dakar', 'country': 'SN', 'province': 'prov-Senegal-2'}
# {'id': 'cty-Senegal-Pikine', 'country': 'SN', 'province': 'prov-Senegal-2'}
# {'id': 'cty-Senegal-Guediawaye', 'country': 'SN', 'province': 'prov-Senegal-2'}
# {'id': 'cty-Senegal-Rufisque', 'country': 'SN', 'province': 'prov-Senegal-2'}
# {'id': 'cty-Senegal-Diourbel', 'country': 'SN', 'province': 'prov-Senegal-3'}
# {'id': 'cty-Senegal-Fatick', 'country': 'SN', 'province': 'prov-Senegal-4'}
# {'id': 'cty-Senegal-4', 'country': 'SN', 'province': 'prov-Senegal-5'}
# {'id': 'cty-Senegal-Kolda', 'country': 'SN', 'province': 'prov-Senegal-6'}
# {'id': 'cty-Senegal-Louga', 'country': 'SN', 'province': 'prov-Senegal-7'}
# {'id': 'cty-Senegal-5', 'country': 'SN', 'province': 'prov-Senegal-8'}
# {'id': 'cty-Senegal-Tambacounda', 'country': 'SN', 'province': 'prov-Senegal-9'}
# {'id': 'cty-Senegal-3', 'country': 'SN', 'province': 'prov-Senegal-10'}
# {'id': 'cty-Senegal-MBour', 'country': 'SN', 'province': 'prov-Senegal-10'}
# {'id': 'cty-Senegal-6', 'country': 'SN', 'province': 'prov-Senegal-11'}
# {'id': 'cty-Senegal-Matam', 'country': 'SN', 'province': 'prov-Senegal-12'}
# {'id': 'cty-Senegal-Sedhiou', 'country': 'SN', 'province': 'prov-Senegal-13'}
# {'id': 'cty-Senegal-Kedougou', 'country': 'SN', 'province': 'prov-Senegal-14'}
# {'id': 'cty-Senegal-Kaffrine', 'country': 'SN', 'province': 'prov-Senegal-15'}
# {'id': 'cty-Guinea-Bissau-Bissau', 'country': 'GNB'}
# {'id': 'cty-Sierra-Leone-Freetown', 'country': 'WAL'}
# {'id': 'cty-Sierra-Leone-Bo', 'country': 'WAL'}
# {'id': 'cty-Uganda-Kampala', 'country': 'EAU', 'province': 'prov-EAU-1'}
# {'id': 'cty-Uganda-Mukono', 'country': 'EAU', 'province': 'prov-EAU-1'}
# {'id': 'cty-Uganda-Jinja', 'country': 'EAU', 'province': 'prov-EAU-2'}
# {'id': 'cty-Uganda-Gulu', 'country': 'EAU', 'province': 'prov-EAU-3'}
# {'id': 'cty-Uganda-Mbarara', 'country': 'EAU', 'province': 'prov-EAU-4'}
# {'id': 'cty-Lesotho-Maseru', 'country': 'LS'}
# {'id': 'cty-Madagascar-5', 'country': 'RM'}
# {'id': 'cty-Madagascar-2', 'country': 'RM'}
# {'id': 'cty-Madagascar-8', 'country': 'RM'}
# {'id': 'cty-Madagascar-3', 'country': 'RM'}
# {'id': 'cty-Madagascar-6', 'country': 'RM'}
# {'id': 'cty-Madagascar-4', 'country': 'RM'}
# {'id': 'cty-Madagascar-7', 'country': 'RM'}
# {'id': 'cty-Malawi-Lilongwe', 'country': 'MW'}
# {'id': 'cty-Malawi-Blantyre', 'country': 'MW'}
# {'id': 'cty-Mozambique-Pemba', 'country': 'MOC', 'province': 'prov-Mozambique-2'}
# {'id': 'cty-Mozambique-Xai-Xai', 'country': 'MOC', 'province': 'prov-Mozambique-3'}
# {'id': 'cty-Mozambique-Inhambane', 'country': 'MOC', 'province': 'prov-Mozambique-4'}
# {'id': 'cty-Mozambique-9', 'country': 'MOC', 'province': 'prov-Mozambique-5'}
# {'id': 'cty-Mozambique-7', 'country': 'MOC', 'province': 'prov-Mozambique-6'}
# {'id': 'cty-Mozambique-3', 'country': 'MOC', 'province': 'prov-Mozambique-6'}
# {'id': 'cty-Mozambique-5', 'country': 'MOC', 'province': 'prov-Mozambique-7'}
# {'id': 'cty-Mozambique-Lichinga', 'country': 'MOC', 'province': 'prov-Mozambique-8'}
# {'id': 'cty-Mozambique-4', 'country': 'MOC', 'province': 'prov-Mozambique-9'}
# {'id': 'cty-Mozambique-8', 'country': 'MOC', 'province': 'prov-Mozambique-10'}
# {'id': 'cty-Mozambique-6', 'country': 'MOC', 'province': 'prov-Mozambique-11'}
# {'id': 'cty-Mozambique-2', 'country': 'MOC', 'province': 'prov-Mozambique-13'}
# {'id': 'cty-Mauritius-Port-Louis', 'country': 'MS'}
# {'id': 'city-Mamoutzou-MAYO-MAYO', 'is_country_cap': 'yes', 'country': 'MAYO'}
# {'id': 'cty-Swaziland-Mbabane', 'country': 'SD'}
# {'id': 'city-Saint-Denis-REUN-REUN', 'is_country_cap': 'yes', 'country': 'REUN'}
# {'id': 'cty-Saint-Paul-REUN-REUN', 'country': 'REUN'}
# {'id': 'city-Jamestown-HELX-HELX', 'is_country_cap': 'yes', 'country': 'HELX'}
# {'id': 'cty-Sao-Tome-and-Principe-Sao-Tome', 'country': 'STP'}
# {'id': 'cty-Seychelles-Victoria', 'country': 'SY'}
